# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:llama3.2",
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='5555f470-68a7-4b01-b865-4df6d2044027'),
#               AIMessage(content="I don't have any information about your favourite colour. This is the beginning of our conversation, and I don't have any prior knowledge about you. Would you like to tell me your favourite colour?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-14T06:00:04.082774211Z', 'done': True, 'done_reason': 'stop', 'total_duration': 987997599, 'load_duration': 151453598, 'prompt_eval_count': 31, 'prompt_eval_duration': 242890237, 'eval_count': 41, 'eval_duration': 572406794, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09e80-4b13-7d81-9913-c30b5052a036-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 41, 'total_tokens': 72})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="ollama:llama3.2",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='7b481ec9-7900-4a28-b606-28c1d7c861c5'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-14T06:00:28.880884876Z', 'done': True, 'done_reason': 'stop', 'total_duration': 685545342, 'load_duration': 142782079, 'prompt_eval_count': 174, 'prompt_eval_duration': 225133182, 'eval_count': 27, 'eval_duration': 304753048, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09e80-ad21-7c60-8270-3db29633d1fb-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {'user': 'object', 'favourite_colour': 'nil'}, 'id': '33748788-446f-49c1-b603-73f144274049', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 174, 'output_tokens': 27, 'total_tokens': 201}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='1fd98ae8-2f8f-42ef-bfa2-ff83b089bd0c', tool_call_id='33748788-446f-49c1-b603-73f144274049'),
#               AIMessage(content='It seems like the API response provided the favourite colour, which is blue.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-14T06:00:29.240257737Z', 'done': True, 'done_reason': 'stop', 'total_duration': 351103818, 'load_duration': 146586383, 'prompt_eval_count': 98, 'prompt_eval_duration': 25413098, 'eval_count': 16, 'eval_duration': 167881300, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09e80-afd7-7050-ab56-8edc25591e26-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 98, 'output_tokens': 16, 'total_tokens': 114})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='5e923180-7d40-43de-98cc-56f006fc5e07'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-14T06:00:38.836224149Z', 'done': True, 'done_reason': 'stop', 'total_duration': 723016286, 'load_duration': 132968424, 'prompt_eval_count': 174, 'prompt_eval_duration': 285100337, 'eval_count': 26, 'eval_duration': 292851234, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09e80-d3df-73c0-b399-795c9c9fd013-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {'object': {'favourite_colour': 'blue'}}, 'id': '99d5fb93-e3f4-47fe-ab74-fb22c2dc2742', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 174, 'output_tokens': 26, 'total_tokens': 200}),
#               ToolMessage(content='green', name='get_favourite_colour', id='6b78ffbc-1a5a-4554-ae54-98ec4a71d4ba', tool_call_id='99d5fb93-e3f4-47fe-ab74-fb22c2dc2742'),
#               AIMessage(content="Based on the tool call response, it appears that the tool has retrieved the user's favourite colour, which is green.", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-14T06:00:39.274919598Z', 'done': True, 'done_reason': 'stop', 'total_duration': 430485253, 'load_duration': 130016725, 'prompt_eval_count': 97, 'prompt_eval_duration': 23342587, 'eval_count': 25, 'eval_duration': 261519050, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09e80-d6bb-7221-95bd-8007a7f68edc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 25, 'total_tokens': 122})]}
