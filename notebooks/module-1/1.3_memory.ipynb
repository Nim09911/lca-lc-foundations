# %%
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "ollama:llama3.2"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='05750e37-e00a-4857-abdc-5118370a56e7'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a wonderful colour, isn't it? It's so calming and refreshing. Do you have a particular shade of green that you prefer? Is it lime, olive, or perhaps forest green?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-13T09:55:20.57213539Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5740818794, 'load_duration': 5181008633, 'prompt_eval_count': 37, 'prompt_eval_duration': 35874815, 'eval_count': 52, 'eval_duration': 496047815, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09a31-42f1-7631-a8c2-b35491633553-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 52, 'total_tokens': 89})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='abbb6ae9-fbdb-493c-af1f-451cf0465078'),
#               AIMessage(content="I don't have any information about your favourite colour, as I'm a text-based AI assistant and our conversation just started. Would you like to share your favourite colour with me?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-13T09:55:21.174593284Z', 'done': True, 'done_reason': 'stop', 'total_duration': 570540694, 'load_duration': 146786384, 'prompt_eval_count': 31, 'prompt_eval_duration': 47624243, 'eval_count': 37, 'eval_duration': 356192209, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09a31-5999-7980-87d0-d97477bcf97e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 37, 'total_tokens': 68})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "ollama:llama3.2",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ba90d24e-b0bd-43c7-b3ef-be138a559675'),
#               AIMessage(content="Hello Seán! It's great to meet you! Green is a wonderful colour, isn't it? From lush forests to vibrant emeralds, it's a colour that can bring a sense of calmness and growth. What is it about the colour green that you particularly enjoy? Is it a favourite for your clothes, home decor, or perhaps a favourite hobby?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-13T09:55:22.16161999Z', 'done': True, 'done_reason': 'stop', 'total_duration': 896880281, 'load_duration': 144321041, 'prompt_eval_count': 37, 'prompt_eval_duration': 17808886, 'eval_count': 75, 'eval_duration': 706923786, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09a31-5c2e-7b92-9385-70d031107585-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 75, 'total_tokens': 112})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ba90d24e-b0bd-43c7-b3ef-be138a559675'),
#               AIMessage(content="Hello Seán! It's great to meet you! Green is a wonderful colour, isn't it? From lush forests to vibrant emeralds, it's a colour that can bring a sense of calmness and growth. What is it about the colour green that you particularly enjoy? Is it a favourite for your clothes, home decor, or perhaps a favourite hobby?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-13T09:55:22.16161999Z', 'done': True, 'done_reason': 'stop', 'total_duration': 896880281, 'load_duration': 144321041, 'prompt_eval_count': 37, 'prompt_eval_duration': 17808886, 'eval_count': 75, 'eval_duration': 706923786, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09a31-5c2e-7b92-9385-70d031107585-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 75, 'total_tokens': 112}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='43e7dc62-3d19-4eae-9d6c-22242dc28c54'),
#               AIMessage(content='I remember! Your favourite colour is green!', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-13T09:55:22.429827378Z', 'done': True, 'done_reason': 'stop', 'total_duration': 240952861, 'load_duration': 115462181, 'prompt_eval_count': 127, 'prompt_eval_duration': 16681306, 'eval_count': 10, 'eval_duration': 90238821, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09a31-5fcb-7e83-9b89-6990f25f7a83-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 127, 'output_tokens': 10, 'total_tokens': 137})]}
