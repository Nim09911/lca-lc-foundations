# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='ollama:llama3.2',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# I'm happy to create a capital city for the Moon, but I must note that there is no actual capital city on the Moon. However, I can propose a concept for a futuristic capital city on the lunar surface.
#
# Introducing "Lunaria" - the capital city of the Moon!
#
# **Location:** Lunaria is situated in the northern hemisphere of the Moon, in a vast, impact crater known as the "Lunar Oasis." This crater provides a natural habitat for the city, with a stable and relatively flat terrain.
#
# **Architecture:** Lunaria is a marvel of modern architecture, with sleek, curved skyscrapers that seem to defy gravity. The city's buildings are made from a durable, moon-specific material that can withstand the harsh lunar environment. The structures are covered in a reflective, silver-gray coating to minimize heat absorption and maximize energy efficiency.
#
# **Layout:** Lunaria is divided into four main districts:
#
# 1. **The Spire of Enlightenment**: The central hub of the city, where the Lunar Council and various scientific institutions are located. This district features a grand, towering spire that serves as a symbol of the city's intellectual and scientific prowess.
# 2. **The Haven of Innovation**: An area dedicated to cutting-edge research and development, with numerous labs, workshops, and incubators for startups. This district is home to some of the most brilliant minds in lunar science and technology.
# 3. **The Marketplace of the Moon**: A bustling commercial center where lunar resources are traded, sold, and exchanged. This district features a vast, sprawling bazaar with shops, restaurants, and entertainment venues.
# 4. **The Lunar Sanctuary**: A tranquil, natural oasis in the heart of the city, designed to promote relaxation and rejuvenation. This district features lush gardens, serene water features, and plenty of recreational spaces.
#
# **Innovative Features:** Lunaria boasts several innovative features that make it an exemplary city on the Moon. These include:
#
# * Advanced water management systems, which harness and recycle every precious drop of water available on the lunar surface.
# * State-of-the-art life support systems, which maintain a stable atmosphere and climate within the city.
# * A network of underground tunnels and habitats, providing safe shelter from lunar radiation and extreme temperature fluctuations.
#
# **Population:** Lunaria is home to a diverse population of approximately 50,000 lunar citizens, as well as a significant number of tourists, scientists, and researchers from around the world.
#
# I hope you've enjoyed this concept for the capital city of the Moon, Lunaria!

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': '1667191192207.png', 'type': 'image/png', 'size': 1225058, 'content': <memory at 0x736621dbfdc0>, 'last_modified': datetime.datetime(2022, 10, 31, 4, 39, 56, 526000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this base64 image"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# I don't see an image. You mentioned an image in your request, but it's not visible in this chat format. Can you please provide the text representation of the image, like a base64 encoded string, or describe the image to me so I can better understand your request?
#
# If you'd like, I can help you create a capital city based on your description, and I'll do my best to bring it to life in words!

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import sounddevice as sd
#       2 from scipy.io.wavfile import write
#       3 import base64
#       4 import io
#
# File ~/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:72
#      70             break
#      71     else:
# ---> 72         raise OSError('PortAudio library not found')
#      73     _lib: ... = _ffi.dlopen(_libname)
#      74 except OSError:
#
# OSError: PortAudio library not found

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
