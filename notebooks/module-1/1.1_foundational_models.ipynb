# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama3.2", 
    model_provider="ollama",
    base_url="http://localhost:11434",
    options={
        "num_ctx": 16348
    }
)

# %%
response = model.invoke("What is the temperature today ?")

response
# Out:
# AIMessage(content="I'm not capable of providing real-time weather information or temperature readings. However, I can suggest some ways for you to find out the current temperature in your area:\n\n1. Check online weather websites: You can check websites like AccuWeather, Weather.com, or the National Weather Service (NWS) for current weather conditions and temperature readings.\n2. Use a weather app: You can download a weather app on your smartphone that provides current weather conditions, temperature, and forecast.\n3. Check local news: You can watch local news or check local newspapers for current weather information.\n4. Use voice assistants: You can ask voice assistants like Siri, Google Assistant, or Alexa to provide you with the current temperature.\n\nPlease note that I'm a text-based AI model, and I don't have real-time access to current weather information.", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-12T16:25:44.732507459Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3048338927, 'load_duration': 167808660, 'prompt_eval_count': 31, 'prompt_eval_duration': 180969332, 'eval_count': 168, 'eval_duration': 2562990640, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09670-5e1e-7c33-97ed-a394e6df2246-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 168, 'total_tokens': 199})

# %%
print(response.content)
# Out:
# I'm not capable of providing real-time weather information or temperature readings. However, I can suggest some ways for you to find out the current temperature in your area:
#
# 1. Check online weather websites: You can check websites like AccuWeather, Weather.com, or the National Weather Service (NWS) for current weather conditions and temperature readings.
# 2. Use a weather app: You can download a weather app on your smartphone that provides current weather conditions, temperature, and forecast.
# 3. Check local news: You can watch local news or check local newspapers for current weather information.
# 4. Use voice assistants: You can ask voice assistants like Siri, Google Assistant, or Alexa to provide you with the current temperature.
#
# Please note that I'm a text-based AI model, and I don't have real-time access to current weather information.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-09-12T16:25:44.732507459Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 168,
#  'eval_duration': 2562990640,
#  'load_duration': 167808660,
#  'logprobs': None,
#  'model': 'llama3.2',
#  'model_name': 'llama3.2',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 31,
#  'prompt_eval_duration': 180969332,
#  'total_duration': 3048338927}

# %% [markdown]
# ## Customising your Model

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1716aa3e-a944-4492-96b3-a4471fa36399'),
#               AIMessage(content="There is no capital of the Moon. The Moon is a natural satellite of Earth and does not have any permanent human settlements or a government that would need a capital city. It's simply a rocky, airless body that orbits our planet.", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-12T16:25:46.142595954Z', 'done': True, 'done_reason': 'stop', 'total_duration': 979879070, 'load_duration': 213477624, 'prompt_eval_count': 33, 'prompt_eval_duration': 20639226, 'eval_count': 49, 'eval_duration': 704712661, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09670-6bc7-77e2-9aa2-d19feaa42487-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 49, 'total_tokens': 82})]}

# %%
print(response['messages'][-1].content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite of Earth and does not have any permanent human settlements or a government that would need a capital city. It's simply a rocky, airless body that orbits our planet.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='8f684aa5-563e-498b-bc0b-c482402d8d64'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='a98afd26-0c5f-4f51-9e77-12e8830d767f', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='8a49e3b6-9d13-494d-95a6-64cd719247c4'),
#               AIMessage(content="I need to correct myself. There is no capital city on the Moon. The Moon is a natural satellite of Earth and does not have a permanent human settlement or a functioning government. It's a celestial body that has been explored by humans through space missions, but there are no permanent cities or infrastructure on the Moon.\n\nMy previous response was an error, and I appreciate you bringing it to my attention. I strive to provide accurate and reliable information, and I'll make sure to correct my knowledge on this topic.", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-09-12T16:25:48.180003869Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1976897440, 'load_duration': 219967975, 'prompt_eval_count': 60, 'prompt_eval_duration': 23126233, 'eval_count': 103, 'eval_duration': 1639837823, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--01a09670-6fd7-75b3-a863-de19809b3f15-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 103, 'total_tokens': 163})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# I'm afraid I have some disappointing news for you.
#
# There is no city called Luna City on the Moon. In fact, there is no human settlement or city on the Moon at all. While there have been several manned missions to the Moon in the past, including those by NASA's Apollo program in the late 1960s and early 1970s, no permanent city or human settlement has been established on the Moon.
#
# However, there are plans to return humans to the Moon in the near future, with NASA's Artemis program aiming to send the first woman and the next man to the Moon by 2025. The ultimate goal of the program is to establish a sustainable presence on the Moon, which could potentially include a lunar base or a city.
#
# But as of now, there is no Luna City on the Moon. The Moon remains a barren, airless rock that is devoid of human habitation.
#
# If you're interested in learning more about the Moon or space exploration, I'd be happy to help!

# %%
from IPython import get_ipython

# This triggers a clean shutdown request directly to the Jupyter server
get_ipython().kernel.do_shutdown(restart=False)
# Out:
# {'status': 'ok', 'restart': False}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
